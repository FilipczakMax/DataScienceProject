# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
seeds = pd.read_csv('MNCAATourneySeeds.csv')
regular_season = pd.read_csv('MRegularSeasonCompactResults.csv')
seeds['SeedInt'] = seeds['Seed'].apply(lambda x: int(x[1:3]))
w_margin = regular_season.groupby(['Season', 'WTeamID'])['WScore'].mean() - \
           regular_season.groupby(['Season', 'WTeamID'])['LScore'].mean()
